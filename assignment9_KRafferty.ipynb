# %% [markdown]
# # **Assignment 9**

# %%
# core

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# ml
from sklearn import datasets as ds
from sklearn import linear_model as lm
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.model_selection import train_test_split as tts

# %%
# Load datasets here once and assign to variables iris and boston

iris = ds.load_iris()

# %% [markdown]
# **Q1**
#
# **Data set: Iris**
#
# * Return the first 5 rows of the data including the feature names as column headings in a DataFrame and a
# separate Python list containing target names

# %%
df_iris = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_targets = list(iris.target)
print(df_iris.head(5))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# **Q2**
#
# **Data set: Iris**
#
# * Fit the Iris dataset into a kNN model with neighbors=5 and predict the category of observations passed in
# argument new_observations. Return back the target names of each prediction (and not their encoded values,
#  i.e. return setosa instead of 0).

# %%
X = df_iris
y = iris_targets
knn_iris = KNN(n_neighbors=5)
knn_iris.fit(X,y)
new_observations = knn_iris.predict(X)
new_observations_final = [iris.target_names[prediction] for prediction in new_observations]
print(new_observations_final)
# Out:
# ['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'virginica', 'versicolor', 'virginica', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'virginica', 'versicolor', 'versicolo
# ...

# %% [markdown]
# **Q3**
#
# **Data set: Iris**
#
# * Split the Iris dataset into a train / test model with the split ratio between the two established by the function parameter split.
#
# * Fit KNN with the training data with number of neighbors equal to the function parameter neighbors
#
# * Generate and return back an accuracy score using the test data that was split out

# %%
X_train, X_test, y_train, y_test = tts(X, y, test_size=0.3, random_state=42)
knn_iris_2 = KNN(n_neighbors=5)
knn_iris_2.fit(X_train, y_train)
print("Model Accuracy", knn_iris_2.score(X_test, y_test))
# Out:
# Model Accuracy 1.0
# C:\Users\kjr50\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# **Q4**
#
# **Data set: Iris**
#
# * Generate an overfitting / underfitting curve of kNN each of the testing and training accuracy performance scores series for a range of neighbor (k) values from 1 to 30 and plot the curves (number of neighbors is x-axis, performance score is y-axis on the chart).

# %%
training_accuracies = {}
testing_accuracies = {}
neighbors = np.arange(1, 31)
for neighbor in neighbors:
    knn = KNN(n_neighbors=neighbor)
    knn.fit(X_train, y_train)
    training_accuracies[neighbor] = knn.score(X_train, y_train)
    testing_accuracies[neighbor] = knn.score(X_test, y_test)

plt.figure(figsize=(8, 6))
plt.title("Testing Different Number of Neighbors")
plt.plot(neighbors, training_accuracies.values(), label="Training Accuracy")
plt.plot(neighbors, testing_accuracies.values(), label="Testing Accuracy")
plt.legend()
plt.xlabel("Neighbors")
plt.ylabel("Accuracy")
plt.show()
# Out:
# C:\Users\kjr50\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...
